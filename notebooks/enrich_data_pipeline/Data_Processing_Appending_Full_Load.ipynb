# %%
import pandas as pd
import pyarrow.parquet as pq
import yaml
from pathlib import Path
import glob
import logging
import os


# Logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")


# Load YAML config
def load_tonnage_config(yaml_path):
    with open(yaml_path, "r") as f:
        cfg = yaml.safe_load(f)
    return cfg.get("case_def_vars", {})


# Build daily parquet directory based on config
def build_daily_input_dir(cfg):
    folder_type = cfg.get("folder_type")
    tonnage = cfg.get("tonnage")

    PROJECT_ROOT = Path.cwd().parent.parent
    daily_dir = PROJECT_ROOT / "data" / "curated" / "enriched" / "daily" / folder_type / tonnage

    if not daily_dir.exists():
        raise FileNotFoundError(f"Daily parquet directory not found: {daily_dir}")

    return daily_dir


# Build monthly output directory
def build_monthly_output_dir(cfg):
    folder_type = cfg.get("folder_type")
    tonnage = cfg.get("tonnage")

    PROJECT_ROOT = Path.cwd().parent.parent
    monthly_dir = PROJECT_ROOT / "data" / "curated" / "enriched" / "monthly" / folder_type / tonnage
    monthly_dir.mkdir(parents=True, exist_ok=True)

    return monthly_dir


# Process daily → monthly aggregation
def combine_daily_into_monthly(daily_dir, monthly_dir, tonnage, folder_type):

    parquet_files = sorted(glob.glob(str(daily_dir / "*.parquet")))

    if not parquet_files:
        raise FileNotFoundError(f"No daily parquet files found in {daily_dir}")

    logging.info(f"Found {len(parquet_files)} daily parquet files.")

    # Group files by Year-Month
    monthly_groups = {}

    for fpath in parquet_files:
        fname = Path(fpath).name   # e.g., mav28_can_2022_10_31.parquet
        parts = fname.replace(".parquet", "").split("_")

        # Expected: tonnage, folder_type, YYYY, MM, DD
        year = parts[-3]
        month = parts[-2]

        ym = f"{year}_{month}"
        monthly_groups.setdefault(ym, []).append(fpath)

    logging.info(f"Monthly groups detected: {list(monthly_groups.keys())}")

    # For each month → append and write
    for ym, files in monthly_groups.items():
        df_list = []

        for fp in files:
            df = pd.read_parquet(fp)
            df_list.append(df)

        final_df = pd.concat(df_list, ignore_index=True)

        out_name = f"{tonnage}_{folder_type}_appended_{ym}.parquet"
        out_path = monthly_dir / out_name

        final_df.to_parquet(out_path, index=False)
        logging.info(f"Saved monthly parquet → {out_path}")


# Process one config file
def process_monthly_aggregation(yaml_path):
    cfg = load_tonnage_config(yaml_path)
    tonnage = cfg.get("tonnage")
    folder_type = cfg.get("folder_type")

    logging.info(f"Starting MONTHLY aggregation for {tonnage}/{folder_type}")

    daily_dir = build_daily_input_dir(cfg)
    monthly_dir = build_monthly_output_dir(cfg)

    combine_daily_into_monthly(daily_dir, monthly_dir, tonnage, folder_type)

    logging.info(f"Completed MONTHLY aggregation for {tonnage}/{folder_type}\n")


# Run for all YAML configs
if __name__ == "__main__":
    configs_glob = "../../configs/enrich_data_monthly_configs/*.yml"
    yaml_files = sorted(glob.glob(configs_glob))

    for y in yaml_files:
        try:
            process_monthly_aggregation(y)
        except Exception as e:
            logging.error(f"Failed to process config {y}: {e}")
# Out:
- INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2023_08.parquet
# 2025-11-15 23:37:02,528 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2023_09.parquet
# 2025-11-15 23:37:02,968 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2023_10.parquet
# 2025-11-15 23:37:03,419 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2023_11.parquet
# 2025-11-15 23:37:03,838 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2023_12.parquet
# 2025-11-15 23:37:04,294 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_01.parquet
# 2025-11-15 23:37:04,738 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_02.parquet
# 2025-11-15 23:37:05,210 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_03.parquet
# 2025-11-15 23:37:05,659 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_04.parquet
# 2025-11-15 23:37:06,101 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_05.parquet
# 2025-11-15 23:37:06,542 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_06.parquet
# 2025-11-15 23:37:07,003 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_07.parquet
# 2025-11-15 23:37:07,467 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_08.parquet
# 2025-11-15 23:37:07,918 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_09.parquet
# 2025-11-15 23:37:08,362 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_10.parquet
# 2025-11-15 23:37:08,824 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_11.parquet
# 2025-11-15 23:37:09,242 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2024_12.parquet
# 2025-11-15 23:37:09,698 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2025_01.parquet
# 2025-11-15 23:37:10,109 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2025_02.parquet
# 2025-11-15 23:37:10,563 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2025_03.parquet
# 2025-11-15 23:37:10,986 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2025_04.parquet
# 2025-11-15 23:37:11,450 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2025_05.parquet
# 2025-11-15 23:37:11,886 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2025_06.parquet
# 2025-11-15 23:37:12,368 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2025_07.parquet
# 2025-11-15 23:37:12,823 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2025_08.parquet
# 2025-11-15 23:37:13,254 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2025_09.parquet
# 2025-11-15 23:37:13,674 - INFO - Saved monthly parquet → d:\Data Science Projects\Machine Learning\fuel-cost-optimization\data\curated\enriched\monthly\can\mav31\mav31_can_appended_2025_10.parquet
# 2025-11-15 23:37:13,683 - INFO - Completed MONTHLY aggregation for mav31/can

# %%
import pandas as pd

# Read a Parquet file
p_df = pd.read_parquet("../../data/curated/enriched/monthly/can/mav28/mav28_can_appended_2023_01.parquet")

# %%
p_df.head()
# Out:
#             timestamp vehicleId      reg_no             vin_no  \
# 0 2023-01-01 09:34:00    V00151  MH96PU4691  TUB74ST7FW1ENW6TN
# 1 2023-01-01 09:35:00    V00151  MH96PU4691  TUB74ST7FW1ENW6TN
# 2 2023-01-01 09:36:00    V00151  MH96PU4691  TUB74ST7FW1ENW6TN
# 3 2023-01-01 09:37:00    V00151  MH96PU4691  TUB74ST7FW1ENW6TN
# 4 2023-01-01 09:38:00    V00151  MH96PU4691  TUB74ST7FW1ENW6TN
#
#                 model vehicle_type tonnage           tripId  EngineRPM  \
# 0  Tata Signa 2825.TK        Truck  MAV 28  V00151_TR000001       2012
# 1  Tata Signa 2825.TK        Truck  MAV 28  V00151_TR000001       1353
# 2  Tata Signa 2825.TK        Truck  MAV 28  V00151_TR000001       2047
# 3  Tata Signa 2825.TK        Truck  MAV 28  V00151_TR000001       2096
# 4  Tata Signa 2825.TK        Truck  MAV 28  V00151_TR000001       1721
#
#    Torque  ...  DPF_LampCommand  OBDLampCommand  EngineAmberLampCommand  \
# 0     192  ...              Off          Normal                  Normal
# 1     104  ...              Off          Normal                  Normal
# 2     185  ...              Off          Normal                  Normal
# 3     188  ...              Off          Normal                  Normal
# 4     122  ...              Off          Normal                  Normal
#
#    AirFilterClogging  WaterInFuelIndicator EnginePerformanceBiasLevel  \
# 0             Normal           NotDetected                     Normal
# 1             Normal           NotDetected                     Normal
# 2             Normal           NotDetected               Economy Mode
# 3             Normal           NotDetected               Economy Mode
# 4             Normal           NotDetected                     Normal
#
#   EngineBrakeActiveLampCommand EngineCoolantLevelLowLampCommand  \
# 0                          OFF                           Normal
# 1                          OFF                           Normal
# 2                          OFF                           Normal
# 3                          OFF                           Normal
# 4                          OFF                           Normal
#
#   EngineCoolantTempHighLampCommand EngineRedStopLampCommand
# 0                           Normal                   Normal
# 1                           Normal                   Normal
# 2                           Normal                   Normal
# 3                           Normal                   Normal
# 4                           Normal                   Normal
#
# [5 rows x 30 columns]

# %%
p_df.tail()
# Out:
#                  timestamp vehicleId      reg_no             vin_no  \
# 119645 2023-01-31 08:55:00    V00158  MH57NN4263  CD92UXGXHZ4G451R3
# 119646 2023-01-31 08:56:00    V00158  MH57NN4263  CD92UXGXHZ4G451R3
# 119647 2023-01-31 08:57:00    V00158  MH57NN4263  CD92UXGXHZ4G451R3
# 119648 2023-01-31 08:58:00    V00158  MH57NN4263  CD92UXGXHZ4G451R3
# 119649 2023-01-31 08:59:00    V00158  MH57NN4263  CD92UXGXHZ4G451R3
#
#                     model vehicle_type tonnage           tripId  EngineRPM  \
# 119645  Tata Prima 2830.K        Truck  MAV 28  V00158_TR000095       1521
# 119646  Tata Prima 2830.K        Truck  MAV 28  V00158_TR000095       1918
# 119647  Tata Prima 2830.K        Truck  MAV 28  V00158_TR000095       1833
# 119648  Tata Prima 2830.K        Truck  MAV 28  V00158_TR000095       1395
# 119649  Tata Prima 2830.K        Truck  MAV 28  V00158_TR000095       1767
#
#         Torque  ...  DPF_LampCommand  OBDLampCommand  EngineAmberLampCommand  \
# 119645     126  ...              Off          Normal                  Normal
# 119646     186  ...              Off          Normal                  Normal
# 119647     129  ...              Off          Normal                  Normal
# 119648     145  ...              Off          Normal                  Normal
# 119649     125  ...              Off          Normal                  Normal
#
#         AirFilterClogging  WaterInFuelIndicator EnginePerformanceBiasLevel  \
# 119645             Normal           NotDetected               Economy Mode
# 119646             Normal           NotDetected                 Power Mode
# 119647             Normal           NotDetected                     Normal
# 119648             Normal           NotDetected               Economy Mode
# 119649             Normal           NotDetected               Economy Mode
#
#        EngineBrakeActiveLampCommand EngineCoolantLevelLowLampCommand  \
# 119645                          OFF                           Normal
# 119646                          OFF                           Normal
# 119647                           ON                           Normal
# 119648                          OFF                           Normal
# 119649                          OFF                           Normal
#
#        EngineCoolantTempHighLampCommand EngineRedStopLampCommand
# 119645                           Normal                   Normal
# 119646                           Normal                   Normal
# 119647                           Normal                   Normal
# 119648                           Normal                   Normal
# 119649                           Normal                   Normal
#
# [5 rows x 30 columns]

# %%
p_df.shape
# Out:
# (119650, 30)
